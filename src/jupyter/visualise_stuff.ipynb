# %%
import torch 

some_data = torch.load("/Users/ksc/Desktop/Нейротемка/code_local/Уточнение психофизиологических состояний 2023/3_Усталость и сильная усталость/cache/0.pt")
some_data.shape
# Out:
# /var/folders/z2/jk8j2nn905v4_76cbzdgkrxm0000gn/T/ipykernel_97845/3484459216.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
"minutes", some_data.shape[1] / 250 / 60
# Out:
# ('minutes', 103.71573333333335)

# %%
'roughly training length in config', 256 * 225
# Out:
# ('roughly training length in config', 57600)

# %%
60000 / 250 / 60
# Out:
# 4.0

# %%
some_data[:, :58000]
# Out:
# tensor([[ 1.0414,  1.0521,  0.8816,  ...,  0.8585,  1.1072,  1.3069],
#         [-1.0761, -0.7834, -0.3257,  ...,  0.6834,  0.7311,  0.7718],
#         [ 0.3135,  0.0910,  0.1431,  ...,  0.6775,  1.0526,  1.3110],
#         [-0.2836, -0.1113, -0.1017,  ...,  0.9519,  1.2338,  1.3807]],
#        dtype=torch.float64)

# %%
import os
os.chdir(os.path.join(os.getcwd(), '..'))
from utils.data_utils import turn_into_patches

patched = turn_into_patches(some_data, 250, 225)

# %%
flat_patched = patched.reshape(patched.size(0), -1)

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (20,8)

for i in range(3):
    plt.plot(torch.arange(1000), flat_patched[i, :])

# %%
from utils.data_utils import plot_spec

plot_spec(some_data[0, :60_000], n_fft=250)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600>

# %%
from utils.data_utils import plot_spec

plot_spec(some_data[0, :250 * 8], n_fft=250)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x600>
